# %%
import pyautogui
import time
import keyboard

# %%
#Open Blender
time.sleep(0.5)
pyautogui.moveTo(x=884, y=1050, duration=1)
pyautogui.click()

#Center Mouse
time.sleep(0.5)
pyautogui.moveTo(x=960, y=500, duration=1)

#Delete Inital Objects
time.sleep(0.5)
pyautogui.moveTo(x=1712, y=151, duration=1)
pyautogui.click()

time.sleep(0.5)
keyboard.press('shift')

time.sleep(0.5)
pyautogui.moveTo(x=1712, y=198, duration=1)
pyautogui.click()

time.sleep(0.5)
keyboard.release('shift')

time.sleep(0.5)
keyboard.press_and_release('x')

#Center Mouse
time.sleep(0.5)
pyautogui.moveTo(x=960, y=500, duration=1)

#Add Mesh
time.sleep(0.5)
keyboard.press_and_release('shift+a')

time.sleep(0.5)
pyautogui.moveTo(x=1056, y=500, duration=1)
pyautogui.moveTo(x=1056, y=569, duration=1)
pyautogui.click()

#Adjust Mesh Settings
time.sleep(0.5)
pyautogui.moveTo(x=169, y=902, duration=1)
pyautogui.click()

time.sleep(0.5)
pyautogui.moveTo(x=322, y=641, duration=1)
pyautogui.click()

time.sleep(0.5)
pyautogui.write('16', interval=0.25)

time.sleep(0.5)
keyboard.press_and_release('tab')

time.sleep(0.5)
keyboard.press_and_release('tab')

time.sleep(0.5)
pyautogui.write('50', interval=0.25)

time.sleep(0.5)
keyboard.press_and_release('enter')

#Center Mouse
time.sleep(0.5)
pyautogui.moveTo(x=960, y=500, duration=1)

#Bring Object Into Focus
time.sleep(0.5)
pyautogui.press('del')

#Change to Front View
time.sleep(0.5)
pyautogui.press('num1')

#Enter Edit Mode
time.sleep(0.5)
keyboard.press_and_release('tab')

#Scale by 0.75 in z
time.sleep(0.5)
keyboard.press_and_release('s')

time.sleep(0.5)
keyboard.press_and_release('z')

time.sleep(0.5)
pyautogui.write('.75', interval=0.25)

time.sleep(0.5)
keyboard.press_and_release('enter')

#Click on surrounding edges
time.sleep(0.5)
keyboard.press('alt')

time.sleep(0.5)
pyautogui.moveTo(x=906, y=500, duration=1)
pyautogui.click()

time.sleep(0.5)
keyboard.release('alt')

time.sleep(0.5)
pyautogui.press('num7')

time.sleep(0.5)
keyboard.press('alt')
keyboard.press('shift')

time.sleep(0.5)
pyautogui.moveTo(x=872, y=545, duration=1)
pyautogui.click()
pyautogui.moveTo(x=870, y=480, duration=1)
pyautogui.click()
pyautogui.moveTo(x=825, y=432, duration=1)
pyautogui.click()
pyautogui.moveTo(x=759, y=432, duration=1)
pyautogui.click()
pyautogui.moveTo(x=712, y=478, duration=1)
pyautogui.click()
pyautogui.moveTo(x=712, y=545, duration=1)
pyautogui.click()
pyautogui.moveTo(x=759, y=591, duration=1)
pyautogui.click()

time.sleep(0.5)
keyboard.release('alt')
keyboard.release('shift')

#Scale edges
time.sleep(0.5)
keyboard.press_and_release('s')

time.sleep(0.5)
keyboard.press_and_release('shift+z')

time.sleep(0.5)
pyautogui.write('.75', interval=0.25)

time.sleep(0.5)
keyboard.press_and_release('enter')

#Bevel edges
time.sleep(0.5)
keyboard.press_and_release('ctrl+b')

time.sleep(0.5)
pyautogui.write('.5', interval=0.25)

time.sleep(0.5)
keyboard.press_and_release('enter')

time.sleep(0.5)
pyautogui.moveTo(x=408, y=556, duration=1)
pyautogui.click()

#Select Outer Ring
time.sleep(0.5)
keyboard.press('alt')

time.sleep(0.5)
pyautogui.moveTo(x=743, y=505, duration=1)
pyautogui.click()

time.sleep(0.5)
keyboard.release('alt')

#Select Inner Rings
time.sleep(0.5)
pyautogui.moveTo(x=357, y=72, duration=1)
pyautogui.click()

time.sleep(0.5)
pyautogui.moveTo(x=410, y=476, duration=1)
pyautogui.moveTo(x=661, y=476, duration=1)
pyautogui.moveTo(x=661, y=536, duration=1)
pyautogui.click()

#Change Pivot Point
time.sleep(0.5)
pyautogui.press('.')

time.sleep(0.5)
pyautogui.press('7')

#Select Active Point
time.sleep(0.5)
keyboard.press('shift')

time.sleep(0.5)
pyautogui.moveTo(x=734, y=511, duration=1)
pyautogui.click()

time.sleep(0.5)
pyautogui.click()

time.sleep(0.5)
keyboard.release('shift')

#Flatten Top
time.sleep(0.5)
pyautogui.press('num1')

time.sleep(0.5)
keyboard.press_and_release('s')

time.sleep(0.5)
keyboard.press_and_release('z')

time.sleep(0.5)
pyautogui.write('0', interval=0.25)

time.sleep(0.5)
keyboard.press_and_release('enter')

#Change to Bottom View
time.sleep(0.5)
keyboard.press('ctrl')

time.sleep(0.5)
pyautogui.press('num7')

time.sleep(0.5)
keyboard.release('ctrl')

#Select Outer Ring
time.sleep(0.5)
keyboard.press('alt')

time.sleep(0.5)
pyautogui.moveTo(x=743, y=505, duration=1)
pyautogui.click()

time.sleep(0.5)
keyboard.release('alt')

#Select Inner Rings
time.sleep(0.5)
pyautogui.moveTo(x=357, y=72, duration=1)
pyautogui.click()

time.sleep(0.5)
pyautogui.moveTo(x=410, y=476, duration=1)
pyautogui.moveTo(x=661, y=476, duration=1)
pyautogui.moveTo(x=661, y=536, duration=1)
pyautogui.click()

#Select Active Point
time.sleep(0.5)
keyboard.press('shift')

time.sleep(0.5)
pyautogui.moveTo(x=734, y=511, duration=1)
pyautogui.click()

time.sleep(0.5)
pyautogui.click()

time.sleep(0.5)
keyboard.release('shift')

#Flatten Bottom
time.sleep(0.5)
pyautogui.press('num1')

time.sleep(0.5)
keyboard.press_and_release('s')

time.sleep(0.5)
keyboard.press_and_release('z')

time.sleep(0.5)
pyautogui.write('0', interval=0.25)

time.sleep(0.5)
keyboard.press_and_release('enter')

#Change Pivot Point
time.sleep(0.5)
pyautogui.press('.')

time.sleep(0.5)
pyautogui.press('8')

#Change to Top View
time.sleep(0.5)
pyautogui.press('num7')

#Select Point
time.sleep(0.5)
pyautogui.moveTo(x=734, y=511, duration=1)
pyautogui.click()

#Duplicate Point
time.sleep(0.5)
keyboard.press_and_release('shift+d')

time.sleep(0.5)
keyboard.press_and_release('x')

time.sleep(0.5)
pyautogui.write('37.5', interval=0.25)

time.sleep(0.5)
keyboard.press_and_release('enter')

#Move Cursor
time.sleep(0.5)
keyboard.press_and_release('shift+s')

time.sleep(0.5)
pyautogui.press('3')

#Delete Vertex
time.sleep(0.5)
keyboard.press_and_release('x')

time.sleep(0.5)
pyautogui.click()

#Select Outer Ring
time.sleep(0.5)
keyboard.press('alt')

time.sleep(0.5)
pyautogui.moveTo(x=743, y=505, duration=1)
pyautogui.click()

time.sleep(0.5)
keyboard.release('alt')

#Select Inner Rings
time.sleep(0.5)
pyautogui.moveTo(x=357, y=72, duration=1)
pyautogui.click()

time.sleep(0.5)
pyautogui.moveTo(x=410, y=476, duration=1)
pyautogui.moveTo(x=661, y=476, duration=1)
pyautogui.moveTo(x=661, y=536, duration=1)
pyautogui.click()

#Change to Front View
time.sleep(0.5)
pyautogui.press('num1')

#Spin Top
time.sleep(0.5)
keyboard.press_and_release('alt+e')

time.sleep(0.5)
pyautogui.moveTo(x=583, y=715, duration=1)
pyautogui.click()

time.sleep(0.5)
pyautogui.moveTo(x=322, y=641, duration=1)
pyautogui.click()

time.sleep(0.5)
pyautogui.write('3', interval=0.25)

time.sleep(0.5)
keyboard.press_and_release('tab')

time.sleep(0.5)
pyautogui.write('45', interval=0.25)

time.sleep(0.5)
keyboard.press_and_release('enter')

#Reposition Mouse
time.sleep(0.5)
pyautogui.moveTo(x=769, y=240, duration=1)

#Move Cursor
time.sleep(0.5)
keyboard.press_and_release('shift+s')

time.sleep(0.5)
pyautogui.press('1')

#Scale Pumpkin Stem (Ring 1)
time.sleep(0.5)
keyboard.press('alt')

time.sleep(0.5)
pyautogui.click()

time.sleep(0.5)
keyboard.release('alt')

time.sleep(0.5)
keyboard.press_and_release('s')

time.sleep(0.5)
pyautogui.write('.75', interval=0.25)

time.sleep(0.5)
keyboard.press_and_release('enter')

#Scale Pumpkin Stem (Ring 2)
time.sleep(0.5)
keyboard.press('alt')

time.sleep(0.5)
pyautogui.moveTo(x=789, y=195, duration=1)
pyautogui.click()

time.sleep(0.5)
keyboard.release('alt')

time.sleep(0.5)
keyboard.press_and_release('s')

time.sleep(0.5)
pyautogui.write('.75', interval=0.25)

time.sleep(0.5)
keyboard.press_and_release('enter')

#Scale Pumpkin Stem (Ring 3)
time.sleep(0.5)
keyboard.press('alt')

time.sleep(0.5)
pyautogui.moveTo(x=820, y=155, duration=1)
pyautogui.click()

time.sleep(0.5)
keyboard.release('alt')

time.sleep(0.5)
keyboard.press_and_release('s')

time.sleep(0.5)
pyautogui.write('.75', interval=0.25)

time.sleep(0.5)
keyboard.press_and_release('enter')

#Bevel Pumpkin Stem (Ring 3)
time.sleep(0.5)
keyboard.press_and_release('ctrl+b')

time.sleep(0.5)
pyautogui.write('.5', interval=0.25)

time.sleep(0.5)
keyboard.press_and_release('enter')

#Bevel Pumpkin Stem (Ring 0)
time.sleep(0.5)
keyboard.press('alt')

time.sleep(0.5)
pyautogui.moveTo(x=761, y=291, duration=1)
pyautogui.click()

time.sleep(0.5)
keyboard.release('alt')

time.sleep(0.5)
keyboard.press_and_release('ctrl+b')

time.sleep(0.5)
pyautogui.write('.5', interval=0.25)

time.sleep(0.5)
keyboard.press_and_release('enter')

#Duplicate Object
time.sleep(0.5)
keyboard.press_and_release('a')

time.sleep(0.5)
keyboard.press_and_release('shift+d')

time.sleep(0.5)
keyboard.press_and_release('enter')

#Enter X-Ray View
time.sleep(0.5)
keyboard.press_and_release('alt+z')

#Shrink Object
time.sleep(0.5)
keyboard.press_and_release('alt+s')

time.sleep(0.5)
pyautogui.write('-5', interval=0.25)

time.sleep(0.5)
keyboard.press_and_release('s')

time.sleep(0.5)
keyboard.press_and_release('enter')

#Seperate Objects
time.sleep(0.5)
keyboard.press_and_release('p')

time.sleep(0.5)
pyautogui.click()

#Exit X-Ray View
time.sleep(0.5)
keyboard.press_and_release('alt+z')

#Exit Edit Mode
time.sleep(0.5)
keyboard.press_and_release('tab')

#Rename Pumpkin
time.sleep(0.5)
pyautogui.moveTo(x=1712, y=151, duration=1)
pyautogui.click()
pyautogui.click()

time.sleep(0.5)
pyautogui.write('Pumpkin', interval=0.25)

time.sleep(0.5)
keyboard.press_and_release('enter')

#Hide Pumpkin
time.sleep(0.5)
keyboard.press_and_release('h')

#Rename Pumpkin Boolean 1
time.sleep(0.5)
pyautogui.moveTo(x=1712, y=177, duration=1)
pyautogui.click()
pyautogui.click()

time.sleep(0.5)
pyautogui.write('Pumpkin Boolean 1', interval=0.25)

time.sleep(0.5)
keyboard.press_and_release('enter')

#Reposition Mouse
time.sleep(0.5)
pyautogui.moveTo(x=781, y=333, duration=1)

#Enter Edit Mode
time.sleep(0.5)
keyboard.press_and_release('tab')

#Select Loop
time.sleep(0.5)
keyboard.press('alt')

time.sleep(0.5)
pyautogui.click()

time.sleep(0.5)
keyboard.release('alt')

#Select Inner Rings
time.sleep(0.5)
pyautogui.moveTo(x=357, y=72, duration=1)
pyautogui.click()

time.sleep(0.5)
pyautogui.moveTo(x=410, y=476, duration=1)
pyautogui.moveTo(x=661, y=476, duration=1)
pyautogui.moveTo(x=661, y=536, duration=1)
pyautogui.click()

#Delete Faces
time.sleep(0.5)
keyboard.press_and_release('x')

time.sleep(0.5)
pyautogui.moveTo(x=661, y=585, duration=1)
pyautogui.click()

#Exit Edit Mode
time.sleep(0.5)
keyboard.press_and_release('tab')

#Add Mesh
time.sleep(0.5)
keyboard.press_and_release('shift+a')

time.sleep(0.5)
pyautogui.moveTo(x=654, y=517, duration=1)
pyautogui.moveTo(x=746, y=517, duration=1)
pyautogui.moveTo(x=746, y=642, duration=1)
pyautogui.click()

#Adjust Mesh Settings
time.sleep(0.5)
pyautogui.moveTo(x=322, y=615, duration=1)
pyautogui.click()

time.sleep(0.5)
pyautogui.write('8', interval=0.25)

time.sleep(0.5)
keyboard.press_and_release('tab')

time.sleep(0.5)
pyautogui.write('50', interval=0.25)

time.sleep(0.5)
keyboard.press_and_release('tab')

time.sleep(0.5)
pyautogui.write('50', interval=0.25)

time.sleep(0.5)
keyboard.press_and_release('enter')

#Reposition Mouse
time.sleep(0.5)
pyautogui.moveTo(x=536, y=585, duration=1)

#Enter Edit Mode
time.sleep(0.5)
keyboard.press_and_release('tab')

#Enter X-Ray View
time.sleep(0.5)
keyboard.press_and_release('alt+z')

#Move Cylinder Up
time.sleep(0.5)
keyboard.press_and_release('g')

time.sleep(0.5)
keyboard.press_and_release('z')

time.sleep(0.5)
pyautogui.write('12.5', interval=0.25)

time.sleep(0.5)
keyboard.press_and_release('enter')

#Select Bottom Loop
time.sleep(0.5)
keyboard.press('alt')

time.sleep(0.5)
pyautogui.click()

time.sleep(0.5)
keyboard.release('alt')

#Scale Loop
time.sleep(0.5)
keyboard.press_and_release('s')

time.sleep(0.5)
pyautogui.write('0', interval=0.25)

time.sleep(0.5)
keyboard.press_and_release('enter')

#Reposition Mouse
time.sleep(0.5)
pyautogui.moveTo(x=700, y=400, duration=1)

#Add Loop Cuts
time.sleep(0.5)
keyboard.press_and_release('ctrl+r')

time.sleep(0.5)
pyautogui.write('6', interval=0.25)

time.sleep(0.5)
keyboard.press_and_release('enter')

time.sleep(0.5)
pyautogui.rightClick()

#Select Bottom Loops
time.sleep(0.5)
pyautogui.moveTo(x=579, y=400, duration=1)

time.sleep(0.5)
pyautogui.dragTo(1008, 606, 1, button='left')

#Delete Faces
time.sleep(0.5)
keyboard.press_and_release('x')

time.sleep(0.5)
pyautogui.click()

#Select Bottom Loop
time.sleep(0.5)
pyautogui.moveTo(x=862, y=414, duration=1)

time.sleep(0.5)
keyboard.press('alt')

time.sleep(0.5)
pyautogui.click()

time.sleep(0.5)
keyboard.release('alt')

#Add Face
time.sleep(0.5)
keyboard.press_and_release('f')

#Select Top Loop
time.sleep(0.5)
pyautogui.moveTo(x=862, y=290, duration=1)

time.sleep(0.5)
keyboard.press('alt')

time.sleep(0.5)
pyautogui.click()

time.sleep(0.5)
keyboard.release('alt')

#Delete Top Face
time.sleep(0.5)
keyboard.press_and_release('x')

time.sleep(0.5)
pyautogui.click()

#Duplicate Object
time.sleep(0.5)
keyboard.press_and_release('a')

time.sleep(0.5)
keyboard.press_and_release('shift+d')

time.sleep(0.5)
keyboard.press_and_release('enter')

#Shrink Object
time.sleep(0.5)
keyboard.press_and_release('alt+s')

time.sleep(0.5)
pyautogui.write('-.1', interval=0.25)

time.sleep(0.5)
keyboard.press_and_release('s')

time.sleep(0.5)
keyboard.press_and_release('enter')

#Select Top Loop
time.sleep(0.5)
keyboard.press('alt')

time.sleep(0.5)
pyautogui.click()

time.sleep(0.5)
keyboard.release('alt')

#Add Face
time.sleep(0.5)
keyboard.press_and_release('f')

#Select 2nd Top Loop
time.sleep(0.5)
pyautogui.moveTo(x=862, y=280, duration=1)

time.sleep(0.5)
keyboard.press('alt')

time.sleep(0.5)
pyautogui.click()

time.sleep(0.5)
keyboard.release('alt')

#Add Face
time.sleep(0.5)
keyboard.press_and_release('f')

#Seperate Objects
time.sleep(0.5)
keyboard.press_and_release('p')

time.sleep(0.5)
pyautogui.moveTo(x=861, y=326, duration=1)
pyautogui.click()

#Exit X-Ray View
time.sleep(0.5)
keyboard.press_and_release('alt+z')

#Exit Edit Mode
time.sleep(0.5)
keyboard.press_and_release('tab')

#Hide Pumpkins
time.sleep(0.5)
pyautogui.moveTo(x=1712, y=151, duration=1)

time.sleep(0.5)
keyboard.press_and_release('h')

#Rename Pumpkin Boolean 3
time.sleep(0.5)
pyautogui.click()
pyautogui.click()

time.sleep(0.5)
pyautogui.write('Pumpkin Boolean 3', interval=0.25)

time.sleep(0.5)
keyboard.press_and_release('enter')

#Rename Pumpkin Boolean 2
time.sleep(0.5)
pyautogui.click()
pyautogui.click()

time.sleep(0.5)
pyautogui.write('Pumpkin Boolean 2', interval=0.25)

time.sleep(0.5)
keyboard.press_and_release('enter')

#Select Pumpkin Boolean 1
time.sleep(0.5)
pyautogui.moveTo(x=1712, y=177, duration=1)
pyautogui.click()

#Reposition Mouse
time.sleep(0.5)
pyautogui.moveTo(x=1478, y=292, duration=1)

#Add Subdivision Modifier
time.sleep(0.5)
keyboard.press_and_release('ctrl+3')

#Select Modifier Properties
time.sleep(0.5)
pyautogui.moveTo(x=1602, y=724, duration=1)
pyautogui.click()

#Add Boolean Modifier
time.sleep(0.5)
pyautogui.moveTo(x=1682, y=456, duration=1)
pyautogui.click()

time.sleep(0.5)
pyautogui.moveTo(x=1434, y=579, duration=1)
pyautogui.click()

#Add Boolean Modifier
time.sleep(0.5)
pyautogui.moveTo(x=1682, y=456, duration=1)
pyautogui.click()

time.sleep(0.5)
pyautogui.moveTo(x=1434, y=579, duration=1)
pyautogui.click()

#Configure Boolean Union
time.sleep(0.5)
pyautogui.moveTo(x=1768, y=730, duration=1)
pyautogui.click()

time.sleep(0.5)
pyautogui.moveTo(x=1768, y=792, duration=1)
pyautogui.click()

time.sleep(0.5)
pyautogui.moveTo(x=1768, y=564, duration=1)
pyautogui.click()

#Scroll Down
time.sleep(0.5)
pyautogui.moveTo(x=1907, y=564, duration=1)

time.sleep(0.5)
pyautogui.dragTo(1907, 677, 1, button='left')

#Configure Boolean Difference
time.sleep(0.5)
pyautogui.moveTo(x=1768, y=909, duration=1)
pyautogui.click()

time.sleep(0.5)
pyautogui.moveTo(x=1768, y=705, duration=1)
pyautogui.click()

#Hide Pumpkin Boolean 1
time.sleep(0.5)
pyautogui.moveTo(x=1866, y=174, duration=1)
pyautogui.click()

#Unhide Pumpkin
time.sleep(0.5)
pyautogui.moveTo(x=1866, y=149, duration=1)
pyautogui.click()

#Select Pumpkin
time.sleep(0.5)
pyautogui.moveTo(x=1712, y=151, duration=1)
pyautogui.click()

#Reposition Mouse
time.sleep(0.5)
pyautogui.moveTo(x=1478, y=292, duration=1)

#Add Subdivision Modifier
time.sleep(0.5)
keyboard.press_and_release('ctrl+3')

#Add Boolean Modifier
time.sleep(0.5)
pyautogui.moveTo(x=1682, y=456, duration=1)
pyautogui.click()

time.sleep(0.5)
pyautogui.moveTo(x=1434, y=579, duration=1)
pyautogui.click()

#Configure Boolean Difference
time.sleep(0.5)
pyautogui.moveTo(x=1768, y=792, duration=1)
pyautogui.click()

time.sleep(0.5)
pyautogui.moveTo(x=1768, y=541, duration=1)
pyautogui.click()

#Reposition Mouse
time.sleep(0.5)
pyautogui.moveTo(x=823, y=730, duration=1)

#Enter Edit Mode
time.sleep(0.5)
keyboard.press_and_release('tab')

#Select Bottom Loop
time.sleep(0.5)
keyboard.press('alt')

time.sleep(0.5)
pyautogui.click()

time.sleep(0.5)
keyboard.release('alt')

#Adjust Mean Crease
time.sleep(0.5)
keyboard.press_and_release('n')

time.sleep(0.5)
pyautogui.moveTo(x=1436, y=446, duration=1)
pyautogui.click()

time.sleep(0.5)
pyautogui.write('1', interval=0.25)

time.sleep(0.5)
keyboard.press_and_release('enter')

time.sleep(0.5)
keyboard.press_and_release('n')

#Exit Edit Mode
time.sleep(0.5)
keyboard.press_and_release('tab')
